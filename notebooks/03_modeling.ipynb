# %% [markdown]
# # Notebook 3 — Training Model
#
# **Tujuan:** Melatih tiga model machine learning (Random Forest, XGBoost, LightGBM)
# untuk memprediksi label biner **`matches_par_contract`** (apakah kontrak yang dibid manusia
# sama level+strain dengan kontrak par DDS) — gabungan sumber BBO (LIN) + non-BBO
# (PBN), **~49.755 board**.
#
# > **Perubahan arah penelitian (2026-09-18):** target sekarang biner
# > `matches_par_contract`, bukan lagi 36-kelas. Bagian 1b di bawah menjalankan **ablasi
# > fitur** untuk memutuskan apakah 10 kolom trik DD per strain
# > (`ns_dd_*`/`ew_dd_*`) layak dipertahankan sebagai fitur (di samping 164
# > fitur kanonik) — 8 kolom par DDS lainnya SUDAH dikeluarkan permanen di
# > `src/preprocessing/dataset_builder.py` karena jadi bahan langsung label
# > (leakage), tidak butuh ablasi.
# >
# > **Penamaan (2026-09-20)**: kolom target ini sebelumnya bernama
# > `is_optimal`, diganti `matches_par_contract` — nilai/definisi tidak berubah.
#
# Rasionalisasi hyperparameter di bawah (class_weight LightGBM/RF, default
# config XGBoost) berasal dari eksperimen di skema 36-kelas lama — dipakai
# sebagai titik awal yang masuk akal, tapi divalidasi ulang khusus untuk
# `matches_par_contract` di `notebooks/05_improvement_experiments.ipynb`.
#
# **Output yang dihasilkan:**
# - Model tersimpan: `outputs/models/*.pkl`
# - Visualisasi: `outputs/results/nb03_*.png`
#
# **Tahap penelitian:** Tahap 5 (Model)
#
# > **Prasyarat:** `data/processed/` harus sudah ada (dari `01_data_extraction.ipynb` di folder ini).

# %% [markdown]
# ---
# ## 0. Setup

# %%
import sys
import time
import pickle
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import yaml
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

OUT       = ROOT / 'outputs' / 'results'
MODEL_DIR = ROOT / 'outputs' / 'models'
OUT.mkdir(parents=True, exist_ok=True)
MODEL_DIR.mkdir(parents=True, exist_ok=True)

# Sumber kebenaran hyperparameter — TIDAK di-hardcode di notebook (CLAUDE.md
# "Konvensi Kode"). RF & LightGBM sudah termasuk class_weight="balanced" di sini.
CONFIG = yaml.safe_load((ROOT / 'configs' / 'config.yaml').read_text())

plt.rcParams.update({
    'figure.dpi': 120,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 11,
})
sns.set_palette('tab10')
print('Setup selesai. Hyperparameter dimuat dari configs/config.yaml.')
# Out:
# Setup selesai. Hyperparameter dimuat dari configs/config.yaml.

# %% [markdown]
# ---
# ## 1. Load Dataset

# %%
from src.preprocessing import load_splits

df_train, df_val, df_test, feature_cols, le = load_splits(ROOT / 'data' / 'processed')

X_train = df_train[feature_cols].values.astype(np.float32)
y_train = df_train['label'].values
X_val   = df_val[feature_cols].values.astype(np.float32)
y_val   = df_val['label'].values

n_classes  = len(le.classes_)
n_features = len(feature_cols)

print(f'Train  : {X_train.shape}  (matches_par_contract=1 rate: {y_train.mean():.1%})')
print(f'Val    : {X_val.shape}  (matches_par_contract=1 rate: {y_val.mean():.1%})')
print(f'Kelas  : {n_classes}  ->  {list(le.classes_)}')
print(f'Fitur  : {n_features}')
# Out:
# Train  : (34830, 174)  (matches_par_contract=1 rate: 25.2%)
# Val    : (7462, 174)  (matches_par_contract=1 rate: 25.2%)
# Kelas  : 2  ->  [np.int64(0), np.int64(1)]
# Fitur  : 174

# %% [markdown]
# ---
# ## 1b. Ablasi Fitur: Trik DD per Strain (`ns_dd_*`/`ew_dd_*`) — Pakai atau Buang?
#
# 8 kolom par DDS (`dd_par_level`, `dd_par_denom_*`, `dd_par_score`,
# `dd_par_declarer_is_ns`) sudah dikeluarkan permanen dari `feature_columns.json`
# karena jadi bahan langsung label `matches_par_contract` (leakage). 10 kolom trik DD per
# strain (`ns_dd_*`/`ew_dd_*`) tidak langsung membentuk label, tapi sangat
# informatif tentang kontrak par — jadi keputusan pakai/buang divalidasi
# empiris di sini (bukan diasumsikan), dengan RandomForest cepat sebagai probe:
# 174 fitur (164 kanonik + 10 trik DD) vs 164 fitur kanonik saja, dibandingkan
# di validation set. Kriteria: trik DD dipertahankan hanya jika F1 macro naik
# &gt;0.5pp dibanding kanonik saja — kalau tidak, `feature_columns.json` ditulis
# ulang jadi 164 fitur (lebih sederhana, tanpa fitur yang nyaris redundan
# dengan label) dan dipakai konsisten oleh notebook 03-06 berikutnya.

# %%
import json
from sklearn.ensemble import RandomForestClassifier
from src.evaluation import evaluate

DDS_TRICK_COLS = [c for c in feature_cols if c.startswith('ns_dd_') or c.startswith('ew_dd_')]
canonical_cols = [c for c in feature_cols if c not in DDS_TRICK_COLS]

print(f'Fitur penuh (kanonik + trik DD) : {len(feature_cols)}')
print(f'Fitur kanonik saja              : {len(canonical_cols)}')
print(f'Trik DD yang diuji               : {DDS_TRICK_COLS}')

probe_results = {}
for label, cols in [('174 fitur (+ trik DD)', feature_cols), ('164 fitur (kanonik saja)', canonical_cols)]:
    Xtr = df_train[cols].values.astype(np.float32)
    Xva = df_val[cols].values.astype(np.float32)
    probe = RandomForestClassifier(n_estimators=200, random_state=42, n_jobs=-1, class_weight='balanced')
    probe.fit(Xtr, y_train)
    y_pred_p  = probe.predict(Xva)
    y_proba_p = probe.predict_proba(Xva)
    res = evaluate(y_val, y_pred_p, y_proba_p, le, model_name=label)
    probe_results[label] = res
    print(f'  {label:<26}: F1 macro = {res["f1_macro"]:.4f}  |  ROC-AUC = {res["roc_auc"]:.4f}')

f1_full = probe_results['174 fitur (+ trik DD)']['f1_macro']
f1_can  = probe_results['164 fitur (kanonik saja)']['f1_macro']
diff_pp = (f1_full - f1_can) * 100

KEEP_DDS_TRICKS = diff_pp > 0.5
print(f'\nSelisih F1 macro (174 - 164) = {diff_pp:+.2f}pp -> '
      f'{"PERTAHANKAN" if KEEP_DDS_TRICKS else "BUANG"} trik DD (ambang +0.5pp).')

feat_path = ROOT / 'data' / 'processed' / 'feature_columns.json'
if KEEP_DDS_TRICKS:
    print(f'feature_columns.json tetap {len(feature_cols)} fitur (tidak diubah).')
else:
    feat_path.write_text(json.dumps(canonical_cols, indent=2))
    feature_cols = canonical_cols
    X_train = df_train[feature_cols].values.astype(np.float32)
    X_val   = df_val[feature_cols].values.astype(np.float32)
    n_features = len(feature_cols)
    print(f'feature_columns.json ditulis ulang -> {len(feature_cols)} fitur '
          f'(trik DD dibuang). X_train/X_val dibangun ulang dengan fitur ini.')
# Out:
# Fitur penuh (kanonik + trik DD) : 174
# Fitur kanonik saja              : 164
# Trik DD yang diuji               : ['ns_dd_S', 'ew_dd_S', 'ns_dd_H', 'ew_dd_H', 'ns_dd_D', 'ew_dd_D', 'ns_dd_C', 'ew_dd_C', 'ns_dd_N', 'ew_dd_N']
#   174 fitur (+ trik DD)     : F1 macro = 0.7348  |  ROC-AUC = 0.8097
#   164 fitur (kanonik saja)  : F1 macro = 0.6927  |  ROC-AUC = 0.7755
#
# Selisih F1 macro (174 - 164) = +4.21pp -> PERTAHANKAN trik DD (ambang +0.5pp).
# feature_columns.json tetap 174 fitur (tidak diubah).

# %% [markdown]
# ---
# ## 2. Definisi Model & Hyperparameter
#
# Ketiga model memakai hyperparameter dari `configs/config.yaml` **apa adanya**
# (dimuat sebagai `CONFIG` di sel setup — tidak ada angka yang di-hardcode di
# notebook, sesuai "Konvensi Kode" di `CLAUDE.md`).
#
# - **RandomForest & LightGBM**: `class_weight="balanced"` sudah termasuk di
#   config — melawan class imbalance ekstrem. Untuk LightGBM ini adalah kandidat
#   terbaik proyek (F1 macro naik besar, accuracy nyaris tanpa trade-off; jauh
#   lebih baik dari RandomOverSampler/SMOTE yang keduanya menurunkan accuracy
#   >4pp — `experiments/2026-07-15/04_class_imbalance_dds.ipynb`).
# - **XGBoost**: default config (`max_depth=6, learning_rate=0.05, subsample=0.8,
#   colsample_bytree=0.8`). Dikonfirmasi ulang sebagai konfigurasi terbaik di
#   skala **49.755 board / 182 fitur** oleh `notebooks/05_improvement_experiments.ipynb`
#   (Eksperimen A) dan `experiments/2026-07-15/08_baseline_dds_default.ipynb` —
#   mengalahkan hyperparameter "acc-tuned" lama di **semua** metrik. Hyperparameter
#   "acc-tuned" itu di-tuning di dataset 10.223 board (2026-07-15) dan kini usang.

# %%
from src.models import RFModel, XGBModel, LGBMModel

# Semua hyperparameter dari configs/config.yaml (CONFIG, di sel setup).
# RF & LightGBM: class_weight="balanced" sudah ada di config.
# XGBoost: default config — dikonfirmasi terbaik di 49.755 board
# (notebooks/05 Eksperimen A, experiments/2026-07-15/08). Hyperparameter
# "acc-tuned" lama (di-tuning di 10.223 board) sudah usang dan tidak dipakai.
rf_cfg   = CONFIG['models']['random_forest']
xgb_cfg  = CONFIG['models']['xgboost']
lgbm_cfg = CONFIG['models']['lightgbm']

models = [
    RFModel(**rf_cfg),
    XGBModel(**xgb_cfg),
    LGBMModel(**lgbm_cfg),
]

print(f'{"Model":<15} Hyperparameter (configs/config.yaml)')
print('-' * 78)
for name, cfg in [('RandomForest', rf_cfg), ('XGBoost', xgb_cfg), ('LightGBM', lgbm_cfg)]:
    hp = ', '.join(f'{k}={v}' for k, v in cfg.items() if k not in ('random_state', 'n_jobs'))
    print(f'{name:<15} {hp}')
# Out:
# Model           Hyperparameter (configs/config.yaml)
# ------------------------------------------------------------------------------
# RandomForest    n_estimators=300, max_depth=None, min_samples_split=5, class_weight=balanced
# XGBoost         n_estimators=300, max_depth=6, learning_rate=0.05, subsample=0.8, colsample_bytree=0.8
# LightGBM        n_estimators=300, max_depth=-1, learning_rate=0.05, num_leaves=63, subsample=0.8, colsample_bytree=0.8, class_weight=balanced

# %% [markdown]
# ---
# ## 3. Training

# %%
FORCE_RETRAIN = True

trained_models = []
train_times    = {}

for model in models:
    pkl_path = MODEL_DIR / f'{model.name.lower()}.pkl'

    if not FORCE_RETRAIN and pkl_path.exists():
        print(f'[LOAD]  {model.name:<14} <- {pkl_path.name}')
        with open(pkl_path, 'rb') as f:
            m = pickle.load(f)
        trained_models.append(m)
        train_times[model.name] = None
    else:
        if pkl_path.exists():
            pkl_path.unlink()
        print(f'[TRAIN] {model.name:<14} ...', end=' ')
        t0 = time.time()
        model.fit(X_train, y_train)
        elapsed = time.time() - t0
        model.save(pkl_path)
        trained_models.append(model)
        train_times[model.name] = elapsed
        print(f'selesai dalam {elapsed:.1f}s -> disimpan ke {pkl_path.name}')

print('\nSemua model siap.')
# Out:
# [TRAIN] RandomForest   ...
# selesai dalam 63.9s -> disimpan ke randomforest.pkl
# [TRAIN] XGBoost        ...
# selesai dalam 29.0s -> disimpan ke xgboost.pkl
# [TRAIN] LightGBM       ...
# selesai dalam 21.0s -> disimpan ke lightgbm.pkl
#
# Semua model siap.

# %% [markdown]
# ---
# ## 4. Evaluasi pada Validation Set

# %%
from src.evaluation import evaluate, print_summary

val_results = []
for model in trained_models:
    y_pred  = model.predict(X_val)
    y_proba = model.predict_proba(X_val)
    res = evaluate(y_val, y_pred, y_proba, le, model_name=model.name)
    val_results.append(res)
    print_summary(res)
# Out:
# =======================================================
#   RandomForest
# =======================================================
#   Accuracy          : 0.8089
#   Precision (macro) : 0.7472
#   Recall (macro)    : 0.7314
#   F1 (macro)        : 0.7385
#   F1 (weighted)     : 0.8057
#   F1 (positive)     : 0.6028
#   ROC-AUC           : 0.8122
#   PR-AUC (avg prec) : 0.6439
# =======================================================
# =======================================================
#   XGBoost
# =======================================================
#   Accuracy          : 0.8122
#   Precision (macro) : 0.7867
#   Recall (macro)    : 0.6693
#   F1 (macro)        : 0.6950
#   F1 (weighted)     : 0.7887
#   F1 (positive)     : 0.5058
#   ROC-AUC           : 0.8047
#   PR-AUC (avg prec) : 0.6485
# =======================================================
# =======================================================
#   LightGBM
# =======================================================
#   Accuracy          : 0.7979
#   Precision (macro) : 0.7346
#   Recall (macro)    : 0.7529
#   F1 (macro)        : 0.7425
#   F1 (weighted)     : 0.8017
#   F1 (positive)     : 0.6230
#   ROC-AUC           : 0.8250
#   PR-AUC (avg prec) : 0.6795
# =======================================================

# %%
from src.evaluation import compare_models

val_df = compare_models(val_results)
print(f'=== Perbandingan pada Validation Set ({n_features} fitur, 49.755 board, target matches_par_contract) ===')
display(val_df.style
    .format('{:.4f}')
    .highlight_max(color='#C8E6C9', axis=0)
    .set_caption('Hijau = nilai terbaik per metrik'))
# Out:
# === Perbandingan pada Validation Set (174 fitur, 49.755 board, target matches_par_contract) ===
# <style type="text/css">
# #T_33ec1_row0_col4, #T_33ec1_row1_col0, #T_33ec1_row1_col1, #T_33ec1_row2_col2, #T_33ec1_row2_col3, #T_33ec1_row2_col5, #T_33ec1_row2_col6, #T_33ec1_row2_col7 {
#   background-color: #C8E6C9;
# }
# </style>
# <table id="T_33ec1">
#   <caption>Hijau = nilai terbaik per metrik</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33ec1_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_33ec1_level0_col1" class="col_heading level0 col1" >precision_macro</th>
#       <th id="T_33ec1_level0_col2" class="col_heading level0 col2" >recall_macro</th>
#       <th id="T_33ec1_level0_col3" class="col_heading level0 col3" >f1_macro</th>
#       <th id="T_33ec1_level0_col4" class="col_heading level0 col4" >f1_weighted</th>
#       <th id="T_33ec1_level0_col5" class="col_heading level0 col5" >f1_positive</th>
#       <th id="T_33ec1_level0_col6" class="col_heading level0 col6" >roc_auc</th>
#       <th id="T_33ec1_level0_col7" class="col_heading level0 col7" >average_precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33ec1_level0_row0" class="row_heading level0 row0" >RandomForest</th>
#       <td id="T_33ec1_row0_col0" class="data row0 col0" >0.8089</td>
#       <td id="T_33ec1_row0_col1" class="data row0 col1" >0.7472</td>
#       <td id="T_33ec1_row0_col2" class="data row0 col2" >0.7314</td>
#       <td id="T_33ec1_row0_col3" class="data row0 col3" >0.7385</td>
#       <td id="T_33ec1_row0_col4" class="data row0 col4" >0.8057</td>
#       <td id="T_33ec1_row0_col5" class="data row0 col5" >0.6028</td>
#       <td id="T_33ec1_row0_col6" class="data row0 col6" >0.8122</td>
#       <td id="T_33ec1_row0_col7" class="data row0 col7" >0.6439</td>
#     </tr>
#     <tr>
#       <th id="T_33ec1_level0_row1" class="row_heading level0 row1" >XGBoost</th>
#       <td id="T_33ec1_row1_col0" class="data row1 col0" >0.8122</td>
#       <td id="T_33ec1_row1_col1" class="data row1 col1" >0.7867</td>
#       <td id="T_33ec1_row1_col2" class="data row1 col2" >0.6693</td>
#       <td id="T_33ec1_row1_col3" class="data row1 col3" >0.6950</td>
#       <td id="T_33ec1_row1_col4" class="data row1 col4" >0.7887</td>
#       <td id="T_33ec1_row1_col5" class="data row1 col5" >0.5058</td>
#       <td id="T_33ec1_row1_col6" class="data row1 col6" >0.8047</td>
#       <td id="T_33ec1_row1_col7" class="data row1 col7" >0.6485</td>
#     </tr>
#     <tr>
#       <th id="T_33ec1_level0_row2" class="row_heading level0 row2" >LightGBM</th>
#       <td id="T_33ec1_row2_col0" class="data row2 col0" >0.7979</td>
#       <td id="T_33ec1_row2_col1" class="data row2 col1" >0.7346</td>
#       <td id="T_33ec1_row2_col2" class="data row2 col2" >0.7529</td>
#       <td id="T_33ec1_row2_col3" class="data row2 col3" >0.7425</td>
#       <td id="T_33ec1_row2_col4" class="data row2 col4" >0.8017</td>
#       <td id="T_33ec1_row2_col5" class="data row2 col5" >0.6230</td>
#       <td id="T_33ec1_row2_col6" class="data row2 col6" >0.8250</td>
#       <td id="T_33ec1_row2_col7" class="data row2 col7" >0.6795</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## 5. Learning Curve (Performa vs Ukuran Data)

# %%
from sklearn.model_selection import learning_curve
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

train_sizes_abs = np.linspace(0.15, 1.0, 6)

clf_configs = [
    ('Random Forest', RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1, class_weight='balanced')),
    ('XGBoost',       XGBClassifier(n_estimators=100, max_depth=6, learning_rate=0.1, random_state=42, n_jobs=-1, verbosity=0, eval_metric='logloss')),
    ('LightGBM',      LGBMClassifier(n_estimators=100, num_leaves=31, random_state=42, n_jobs=-1, verbose=-1)),
]

fig, ax = plt.subplots(figsize=(10, 6))
colors_lc = ['#4472C4', '#ED7D31', '#70AD47']

for (name, clf), color in zip(clf_configs, colors_lc):
    print(f'Learning curve: {name} ...', end=' ')
    t0 = time.time()
    train_sz, train_sc, val_sc = learning_curve(
        clf, X_train, y_train,
        train_sizes=train_sizes_abs,
        cv=3, scoring='roc_auc',
        n_jobs=-1,
    )
    print(f'{time.time()-t0:.0f}s')

    train_mean = train_sc.mean(axis=1)
    val_mean   = val_sc.mean(axis=1)
    val_std    = val_sc.std(axis=1)

    ax.plot(train_sz, train_mean, '--', color=color, alpha=0.6, lw=1.5)
    ax.plot(train_sz, val_mean,   '-',  color=color, lw=2.5, label=name)
    ax.fill_between(train_sz,
                    val_mean - val_std,
                    val_mean + val_std,
                    alpha=0.12, color=color)

ax.set_title(f'Learning Curve ({n_features} fitur) - ROC-AUC vs Ukuran Training Set\n(garis solid=val, putus-putus=train)', fontweight='bold')
ax.set_xlabel('Ukuran Training Set (sampel)')
ax.set_ylabel('ROC-AUC')
ax.legend(fontsize=10)
plt.tight_layout()
plt.savefig(OUT / 'nb03_learning_curve.png', bbox_inches='tight')
plt.show()
# Out:
# Learning curve: Random Forest ...
# 150s
# Learning curve: XGBoost ...
# 46s
# Learning curve: LightGBM ...
# 69s

# %% [markdown]
# ---
# ## 6. Perbandingan Waktu Training

# %%
timing_results = []
for model_cls, cfg, name in [(RFModel, rf_cfg, 'Random Forest'),
                             (XGBModel, xgb_cfg, 'XGBoost'),
                             (LGBMModel, lgbm_cfg, 'LightGBM')]:
    m = model_cls(**cfg)   # konfigurasi identik dengan model utama di atas
    t0 = time.time()
    m.fit(X_train, y_train)
    elapsed = time.time() - t0
    y_pred = m.predict(X_val)
    from sklearn.metrics import accuracy_score
    acc = accuracy_score(y_val, y_pred)
    timing_results.append({'Model': name, 'Waktu (detik)': elapsed, 'Val Accuracy': acc})
    print(f'{name:<15}: {elapsed:>6.1f}s  |  Val Acc = {acc:.4f}')

timing_df = pd.DataFrame(timing_results)
# Out:
# Random Forest  :   58.3s  |  Val Acc = 0.8089
# XGBoost        :   20.8s  |  Val Acc = 0.8122
# LightGBM       :   18.5s  |  Val Acc = 0.7979

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
colors_m = ['#4472C4', '#ED7D31', '#70AD47']

ax = axes[0]
bars = ax.bar(timing_df['Model'], timing_df['Waktu (detik)'],
              color=colors_m, edgecolor='white', linewidth=1.2)
ax.bar_label(bars, fmt='%.1fs', fontsize=11, padding=3)
ax.set_title('Waktu Training', fontweight='bold')
ax.set_ylabel('Waktu (detik)')
ax.set_ylim(0, timing_df['Waktu (detik)'].max() * 1.2)

ax = axes[1]
bars = ax.bar(timing_df['Model'], timing_df['Val Accuracy'],
              color=colors_m, edgecolor='white', linewidth=1.2)
ax.bar_label(bars, fmt='%.4f', fontsize=11, padding=3)
ax.set_title('Validation Accuracy', fontweight='bold')
ax.set_ylabel('Accuracy')
ax.set_ylim(0, 1.0)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0%}'))

plt.suptitle(f'Waktu Training vs Performa ({n_features} fitur) - Validation Set', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(OUT / 'nb03_training_time.png', bbox_inches='tight')
plt.show()

# %%
# -- Ringkasan Notebook 3 ----------------------------------------
print('=' * 78)
print(f'  RINGKASAN NOTEBOOK 3 - Training Model ({n_features} fitur, target matches_par_contract)')
print('=' * 78)
print(f'  {"Model":<15} {"Val Acc":>9} {"ROC-AUC":>9} {"F1 Mac":>8} {"F1 Pos":>8} {"Waktu":>8}')
print('  ' + '-' * 70)
for res in val_results:
    t = next((r['Waktu (detik)'] for r in timing_results
              if r['Model'].replace(' ', '') == res['model']), None)
    t_str = f'{t:.1f}s' if t else '-'
    print(f'  {res["model"]:<15}'
          f' {res["accuracy"]:>9.4f}'
          f' {res.get("roc_auc", 0):>9.4f}'
          f' {res["f1_macro"]:>8.4f}'
          f' {res.get("f1_positive", 0):>8.4f}'
          f' {t_str:>8}')
print('=' * 78)

best_acc = max(val_results, key=lambda r: r['accuracy'])
best_f1  = max(val_results, key=lambda r: r['f1_macro'])
best_auc = max(val_results, key=lambda r: r.get('roc_auc', 0))
fastest  = min(timing_results, key=lambda r: r['Waktu (detik)'])
print()
print(f'  Accuracy terbaik  : {best_acc["model"]} ({best_acc["accuracy"]:.4f})')
print(f'  F1 Macro terbaik  : {best_f1["model"]} ({best_f1["f1_macro"]:.4f})')
print(f'  ROC-AUC terbaik   : {best_auc["model"]} ({best_auc.get("roc_auc", 0):.4f})')
print(f'  Paling cepat      : {fastest["Model"]} ({fastest["Waktu (detik)"]:.1f}s)')
print()
print('  Lanjut ke: 04_evaluation.ipynb (folder ini) -> Evaluasi final, SHAP, radar chart')
# Out:
# ==============================================================================
#   RINGKASAN NOTEBOOK 3 - Training Model (174 fitur, target matches_par_contract)
# ==============================================================================
#   Model             Val Acc   ROC-AUC   F1 Mac   F1 Pos    Waktu
#   ----------------------------------------------------------------------
#   RandomForest       0.8089    0.8122   0.7385   0.6028    58.3s
#   XGBoost            0.8122    0.8047   0.6950   0.5058    20.8s
#   LightGBM           0.7979    0.8250   0.7425   0.6230    18.5s
# ==============================================================================
#
#   Accuracy terbaik  : XGBoost (0.8122)
#   F1 Macro terbaik  : LightGBM (0.7425)
#   ROC-AUC terbaik   : LightGBM (0.8250)
#   Paling cepat      : LightGBM (18.5s)
#
#   Lanjut ke: 04_evaluation.ipynb (folder ini) -> Evaluasi final, SHAP, radar chart
